# %%
import datetime
import sqlalchemy
import pandas as pd
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, text
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

# %%
# Database Setup
engine = create_engine(f"postgresql+psycopg2://postgres:Bornak632@localhost:5432/final_project")
conn = engine.connect()
# Reflect existing database into a new model
Base = automap_base()

# Reflect the tables
Base.prepare(autoload_with=engine)

# Create session (link) from Python to PG Admin
session = Session(engine)

# Create list and load to dataframe
heart_data_list = []

heart_data = conn.execute(text(""" SELECT * FROM heart_failure """))
for results in heart_data:
    heart_failure = {}
    heart_failure["age"] = results[0]
    heart_failure["sex"] = results[1]
    heart_failure["chest_pain_type"] = results[2]
    heart_failure["resting_bp"] = results[3]
    heart_failure["cholesterol"] = results[4]
    heart_failure["fasting_bs"] = results[5]
    heart_failure["resting_ecg"] = results[6]
    heart_failure["max_hr"] = results[7]
    heart_failure["exercise_aniga"] = results[8]
    heart_failure["old_peak"] = results[9]
    heart_failure["st_slope"] = results[10]
    heart_failure["heart_disease"] = results[11]
    heart_data_list.append(heart_failure)

session.close()
heart_df = pd.DataFrame(heart_data_list)
heart_df
# Out:
#      age sex chest_pain_type  resting_bp  cholesterol  fasting_bs resting_ecg  \
# 0     40   M             ATA         140          289           0      Normal
# 1     49   F             NAP         160          180           0      Normal
# 2     37   M             ATA         130          283           0          ST
# 3     48   F             ASY         138          214           0      Normal
# 4     54   M             NAP         150          195           0      Normal
# ..   ...  ..             ...         ...          ...         ...         ...
# 913   45   M              TA         110          264           0      Normal
# 914   68   M             ASY         144          193           1      Normal
# 915   57   M             ASY         130          131           0      Normal
# 916   57   F             ATA         130          236           0         LVH
# 917   38   M             NAP         138          175           0      Normal
#
#      max_hr exercise_aniga  old_peak st_slope  heart_disease
# 0       172              N       0.0       Up              0
# 1       156              N       1.0     Flat              1
# 2        98              N       0.0       Up              0
# 3       108              Y       1.5     Flat              1
# 4       122              N       0.0       Up              0
# ..      ...            ...       ...      ...            ...
# 913     132              N       1.2     Flat              1
# 914     141              N       3.4     Flat              1
# 915     115              Y       1.2     Flat              1
# 916     174              N       0.0     Flat              1
# 917     173              N       0.0       Up              0
#
# [918 rows x 12 columns]

# %%
heart_df.nunique()
# Out:
# age                 50
# sex                  2
# chest_pain_type      4
# resting_bp          67
# cholesterol        222
# fasting_bs           2
# resting_ecg          3
# max_hr             119
# exercise_aniga       2
# old_peak            53
# st_slope             3
# heart_disease        2
# dtype: int64

# %%
heart_df.dtypes
# Out:
# age                  int64
# sex                 object
# chest_pain_type     object
# resting_bp           int64
# cholesterol          int64
# fasting_bs           int64
# resting_ecg         object
# max_hr               int64
# exercise_aniga      object
# old_peak           float64
# st_slope            object
# heart_disease        int64
# dtype: object

# %%
dummies = pd.get_dummies(heart_df)
dummies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  918 non-null    int64
#  1   resting_bp           918 non-null    int64
#  2   cholesterol          918 non-null    int64
#  3   fasting_bs           918 non-null    int64
#  4   max_hr               918 non-null    int64
#  5   old_peak             918 non-null    float64
#  6   heart_disease        918 non-null    int64
#  7   sex_F                918 non-null    bool
#  8   sex_M                918 non-null    bool
#  9   chest_pain_type_ASY  918 non-null    bool
#  10  chest_pain_type_ATA  918 non-null    bool
#  11  chest_pain_type_NAP  918 non-null    bool
#  12  chest_pain_type_TA   918 non-null    bool
#  13  resting_ecg_LVH      918 non-null    bool
#  14  resting_ecg_Normal   918 non-null    bool
#  15  resting_ecg_ST       918 non-null    bool
#  16  exercise_aniga_N     918 non-null    bool
#  17  exercise_aniga_Y     918 non-null    bool
#  18  st_slope_Down        918 non-null    bool
#  19  st_slope_Flat        918 non-null    bool
#  20  st_slope_Up          918 non-null    bool
# dtypes: bool(14), float64(1), int64(6)
# memory usage: 62.9 KB

# %%
dummies
# Out:
#      age  resting_bp  cholesterol  fasting_bs  max_hr  old_peak  \
# 0     40         140          289           0     172       0.0
# 1     49         160          180           0     156       1.0
# 2     37         130          283           0      98       0.0
# 3     48         138          214           0     108       1.5
# 4     54         150          195           0     122       0.0
# ..   ...         ...          ...         ...     ...       ...
# 913   45         110          264           0     132       1.2
# 914   68         144          193           1     141       3.4
# 915   57         130          131           0     115       1.2
# 916   57         130          236           0     174       0.0
# 917   38         138          175           0     173       0.0
#
#      heart_disease  sex_F  sex_M  chest_pain_type_ASY  ...  \
# 0                0  False   True                False  ...
# 1                1   True  False                False  ...
# 2                0  False   True                False  ...
# 3                1   True  False                 True  ...
# 4                0  False   True                False  ...
# ..             ...    ...    ...                  ...  ...
# 913              1  False   True                False  ...
# 914              1  False   True                 True  ...
# 915              1  False   True                 True  ...
# 916              1   True  False                False  ...
# 917              0  False   True                False  ...
#
#      chest_pain_type_NAP  chest_pain_type_TA  resting_ecg_LVH  \
# 0                  False               False            False
# 1                   True               False            False
# 2                  False               False            False
# 3                  False               False            False
# 4                   True               False            False
# ..                   ...                 ...              ...
# 913                False                True            False
# 914                False               False            False
# 915                False               False            False
# 916                False               False             True
# 917                 True               False            False
#
#      resting_ecg_Normal  resting_ecg_ST  exercise_aniga_N  exercise_aniga_Y  \
# 0                  True           False              True             False
# 1                  True           False              True             False
# 2                 False            True              True             False
# 3                  True           False             False              True
# 4                  True           False              True             False
# ..                  ...             ...               ...               ...
# 913                True           False              True             False
# 914                True           False              True             False
# 915                True           False             False              True
# 916               False           False              True             False
# 917                True           False              True             False
#
#      st_slope_Down  st_slope_Flat  st_slope_Up
# 0            False          False         True
# 1            False           True        False
# 2            False          False         True
# 3            False           True        False
# 4            False          False         True
# ..             ...            ...          ...
# 913          False           True        False
# 914          False           True        False
# 915          False           True        False
# 916          False           True        False
# 917          False          False         True
#
# [918 rows x 21 columns]

# %%
y = dummies["heart_disease"]
X = dummies.drop(columns=["heart_disease"])

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
Scaler = StandardScaler()
X_Scaler = Scaler.fit(X_train)
X_train_scaled = X_Scaler.transform(X_train)
X_test_scaled = X_Scaler.transform(X_test)

# %%
def create_model(hp):
    nn_model = tf.keras.models.Sequential()

    # Allow kerastuner to decide which activation function to use in hidden layers
    activation = hp.Choice('activation',['relu','tanh','sigmoid'])
    
    # Allow kerastuner to decide number of neurons in first layer
    nn_model.add(tf.keras.layers.Dense(units=hp.Int('first_units',
        min_value=1,
        max_value=10,
        step=2), activation=activation, input_dim=20))

    # Allow kerastuner to decide number of hidden layers and neurons in hidden layers
    for i in range(hp.Int('num_layers', 1, 6)):
        nn_model.add(tf.keras.layers.Dense(units=hp.Int('units_' + str(i),
            min_value=1,
            max_value=10,
            step=2),
            activation=activation))
    
    nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

    # Compile the model
    nn_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])
    
    return nn_model

# %%
import keras_tuner as kt

tuner = kt.Hyperband(
    create_model,
    objective="val_accuracy",
    max_epochs=10,
    hyperband_iterations=2)
# Out:
# INFO:tensorflow:Reloading Tuner from .\untitled_project\tuner0.json

# %%
tuner.search(X_train_scaled,y_train,epochs=20,validation_data=(X_test_scaled,y_test))
# Out:
# Trial 56 Complete [00h 00m 09s]
# val_accuracy: 0.5478261113166809
#
# Best val_accuracy So Far: 0.852173924446106
# Total elapsed time: 00h 05m 50s
# INFO:tensorflow:Oracle triggered exit

# %%
best_hyper = tuner.get_best_hyperparameters(1)[0]
best_hyper.values
# Out:
# {'activation': 'relu',
#  'first_units': 9,
#  'num_layers': 2,
#  'units_0': 1,
#  'units_1': 5,
#  'units_2': 7,
#  'units_3': 5,
#  'units_4': 1,
#  'units_5': 7,
#  'tuner/epochs': 20,
#  'tuner/initial_epoch': 0,
#  'tuner/bracket': 0,
#  'tuner/round': 0}

# %%
best_model = tuner.get_best_models(1)[0]
model_loss, model_accuracy = best_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 8/8 - 1s - loss: 0.4645 - accuracy: 0.8522 - 1s/epoch - 149ms/step
# Loss: 0.4645215570926666, Accuracy: 0.852173924446106

# %%
best_model.save("auto_model.h5")
# Out:
# C:\Users\ahmed\anaconda3\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
opt_model = tf.keras.models.load_model('auto_model.h5')

# Show the model architecture
opt_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 9)                 189
#
#  dense_1 (Dense)             (None, 1)                 10
#
#  dense_2 (Dense)             (None, 5)                 10
#
#  dense_3 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 215 (860.00 Byte)
# Trainable params: 215 (860.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# manual nn

# %%
nn_manual_model = tf.keras.models.Sequential()

nn_manual_model.add(tf.keras.layers.Dense(units=9, activation="relu", input_dim=20))

nn_manual_model.add(tf.keras.layers.Dense(units=1, activation="relu"))

nn_manual_model.add(tf.keras.layers.Dense(units=5, activation="relu"))

nn_manual_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

nn_manual_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 9)                 189
#
#  dense_1 (Dense)             (None, 1)                 10
#
#  dense_2 (Dense)             (None, 5)                 10
#
#  dense_3 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 215 (860.00 Byte)
# Trainable params: 215 (860.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
nn_manual_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
fit_model = nn_manual_model.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 22/22 [==============================] - 2s 3ms/step - loss: 0.6931 - accuracy: 0.5480
# Epoch 2/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6849 - accuracy: 0.5552
# Epoch 3/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.6772 - accuracy: 0.5552
# Epoch 4/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.6668 - accuracy: 0.5552
# Epoch 5/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.6514 - accuracy: 0.5552
# Epoch 6/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.6254 - accuracy: 0.5552
# Epoch 7/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.5935 - accuracy: 0.5552
# Epoch 8/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5574 - accuracy: 0.5552
# Epoch 9/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5216 - accuracy: 0.6032
# Epoch 10/100
# 22/22 [==============================] - 0s 2ms/step - loss: 0.4932 - accuracy: 0.8459
# Epoch 11/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.4750 - accuracy: 0.8648
# Epoch 12/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.4629 - accuracy: 0.8750
# Epoch 13/100
# 22/22 [==============================] - 0s 2ms/step - loss: 0.4545 - accuracy: 0.8779
# Epoch 14/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.4464 - accuracy: 0.8837
# Epoch 15/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.4401 - accuracy: 0.8866
# Epoch 16/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.4348 - accuracy: 0.8881
# Epoch 17/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.4299 - accuracy: 0.8881
# Epoch 18/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.4251 - accuracy: 0.8881
# Epoch 19/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.4208 - accuracy: 0.8895
# Epoch 20/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.4164 - accuracy: 0.8924
# Epoch 21/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.4125 - accuracy: 0.8924
# Epoch 22/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.4093 - accuracy: 0.8953
# Epoch 23/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.4055 - accuracy: 0.8983
# Epoch 24/100
# 22/22 [==============================] - 0s 2ms/step - loss: 0.4020 - accuracy: 0.8983
# Epoch 25/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3983 - accuracy: 0.8968
# Epoch 26/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.3944 - accuracy: 0.9012
# Epoch 27/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.3915 - accuracy: 0.9012
# Epoch 28/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3885 - accuracy: 0.8997
# Epoch 29/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.3850 - accuracy: 0.8997
# Epoch 30/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.3823 - accuracy: 0.9041
# Epoch 31/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.3794 - accuracy: 0.9041
# Epoch 32/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.3768 - accuracy: 0.9041
# Epoch 33/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.3743 - accuracy: 0.9041
# Epoch 34/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3717 - accuracy: 0.9041
# Epoch 35/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.3693 - accuracy: 0.9055
# Epoch 36/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.3666 - accuracy: 0.9055
# Epoch 37/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.3645 - accuracy: 0.9041
# Epoch 38/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.3622 - accuracy: 0.9070
# Epoch 39/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.3603 - accuracy: 0.9055
# Epoch 40/100
# 22/22 [==============================] - 0s 2ms/step - loss: 0.3574 - accuracy: 0.9041
# Epoch 41/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.3553 - accuracy: 0.9055
# Epoch 42/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.3531 - accuracy: 0.9041
# Epoch 43/100
# 22/22 [==============================] - 0s 10ms/step - loss: 0.3514 - accuracy: 0.9070
# Epoch 44/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3489 - accuracy: 0.9070
# Epoch 45/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.3469 - accuracy: 0.9055
# Epoch 46/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.3448 - accuracy: 0.9070
# Epoch 47/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.3428 - accuracy: 0.9070
# Epoch 48/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.3407 - accuracy: 0.9070
# Epoch 49/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3388 - accuracy: 0.9084
# Epoch 50/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.3366 - accuracy: 0.9099
# Epoch 51/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.3347 - accuracy: 0.9070
# Epoch 52/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3331 - accuracy: 0.9070
# Epoch 53/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3312 - accuracy: 0.9084
# Epoch 54/100
# 22/22 [==============================] - 0s 2ms/step - loss: 0.3291 - accuracy: 0.9070
# Epoch 55/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3273 - accuracy: 0.9084
# Epoch 56/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3252 - accuracy: 0.9084
# Epoch 57/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3234 - accuracy: 0.9084
# Epoch 58/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3224 - accuracy: 0.9084
# Epoch 59/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.3205 - accuracy: 0.9084
# Epoch 60/100
# 22/22 [==============================] - 0s 2ms/step - loss: 0.3185 - accuracy: 0.9084
# Epoch 61/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.3165 - accuracy: 0.9084
# Epoch 62/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.3152 - accuracy: 0.9084
# Epoch 63/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.3137 - accuracy: 0.9099
# Epoch 64/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3118 - accuracy: 0.9099
# Epoch 65/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3107 - accuracy: 0.9084
# Epoch 66/100
# 22/22 [==============================] - 0s 2ms/step - loss: 0.3096 - accuracy: 0.9084
# Epoch 67/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3077 - accuracy: 0.9070
# Epoch 68/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3065 - accuracy: 0.9084
# Epoch 69/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.3054 - accuracy: 0.9055
# Epoch 70/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.3043 - accuracy: 0.9084
# Epoch 71/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.3029 - accuracy: 0.9055
# Epoch 72/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.3015 - accuracy: 0.9070
# Epoch 73/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.3000 - accuracy: 0.9084
# Epoch 74/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2992 - accuracy: 0.9084
# Epoch 75/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.2980 - accuracy: 0.9084
# Epoch 76/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.2966 - accuracy: 0.9113
# Epoch 77/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.2959 - accuracy: 0.9099
# Epoch 78/100
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2943 - accuracy: 0.9113
# Epoch 79/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.2932 - accuracy: 0.9113
# Epoch 80/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.2921 - accuracy: 0.9084
# Epoch 81/100
# 22/22 [==============================] - 0s 7ms/step - loss: 0.2912 - accuracy: 0.9084
# Epoch 82/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2896 - accuracy: 0.9070
# Epoch 83/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.2887 - accuracy: 0.9084
# Epoch 84/100
# 22/22 [==============================] - 0s 2ms/step - loss: 0.2876 - accuracy: 0.9084
# Epoch 85/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.2868 - accuracy: 0.9099
# Epoch 86/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.2855 - accuracy: 0.9084
# Epoch 87/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.2848 - accuracy: 0.9084
# Epoch 88/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2838 - accuracy: 0.9070
# Epoch 89/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.2828 - accuracy: 0.9070
# Epoch 90/100
# 22/22 [==============================] - 0s 6ms/step - loss: 0.2819 - accuracy: 0.9070
# Epoch 91/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2808 - accuracy: 0.9084
# Epoch 92/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.2793 - accuracy: 0.9099
# Epoch 93/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.2789 - accuracy: 0.9099
# Epoch 94/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2779 - accuracy: 0.9113
# Epoch 95/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.2767 - accuracy: 0.9142
# Epoch 96/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.2762 - accuracy: 0.9142
# Epoch 97/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2751 - accuracy: 0.9128
# Epoch 98/100
# 22/22 [==============================] - 0s 2ms/step - loss: 0.2741 - accuracy: 0.9128
# Epoch 99/100
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2734 - accuracy: 0.9142
# Epoch 100/100
# 22/22 [==============================] - 0s 3ms/step - loss: 0.2725 - accuracy: 0.9142

# %%
model_loss, model_accuracy = nn_manual_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 8/8 - 0s - loss: 0.4737 - accuracy: 0.8261 - 225ms/epoch - 28ms/step
# Loss: 0.4736728370189667, Accuracy: 0.8260869383811951

# %%
nn_manual_model.save("manual_model.h5")
# Out:
# c:\Users\borna\anaconda3\envs\sklearn-env\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
